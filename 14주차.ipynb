# %% [markdown]
# <a href="https://colab.research.google.com/github/skekek2/-/blob/main/14%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
# titanic = sns.load_dataset('raw/titanic') # 앞서 사용한 내장 데이터셋 사용 방법

# %%
titanic= pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/raw/titanic.csv')

titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
titanic.isnull()
# Out:
#      survived  pclass   name    sex    age  sibsp  parch  ticket   fare  \
# 0       False   False  False  False  False  False  False   False  False
# 1       False   False  False  False  False  False  False   False  False
# 2       False   False  False  False  False  False  False   False  False
# 3       False   False  False  False  False  False  False   False  False
# 4       False   False  False  False  False  False  False   False  False
# ..        ...     ...    ...    ...    ...    ...    ...     ...    ...
# 886     False   False  False  False  False  False  False   False  False
# 887     False   False  False  False  False  False  False   False  False
# 888     False   False  False  False   True  False  False   False  False
# 889     False   False  False  False  False  False  False   False  False
# 890     False   False  False  False  False  False  False   False  False
#
#      cabin  embarked
# 0     True     False
# 1    False     False
# 2     True     False
# ...

# %%
titanic.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
# !pip install missingno

# %%
import missingno as msno
msno.matrix(titanic)
# Out:
# <Axes: >

# %%
titanic.isna().any()
# Out:
# survived    False
# pclass      False
# name        False
# sex         False
# age          True
# sibsp       False
# parch       False
# ticket      False
# fare        False
# cabin        True
# embarked     True
# dtype: bool

# %%
titanic.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include=['0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/3554825587.py in <cell line: 0>()
# ----> 1 titanic.describe(include=['0'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11974         max            NaN      3.0
#   11975         """
# > 11976         return describe_ndframe(
#   11977             obj=self,
#   11978             include=include,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      95         )
#      96
# ---> 97     result = describer.describe(percentiles=percentiles)
#      98     return cast(NDFrameT, result)
#      99
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in describe(self, percentiles)
#     165
# ...

# %%
sns.set(style="darkgrid")
sns.countplot(data=titanic, x='survived', hue='sex')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.distplot(titanic.age.loc[titanic['survived'] == 0].kde=False)
sns.distplot(titanic.age.loc[titanic['survived'] == 1].kde=False)
# Out:
#   File "/tmp/ipykernel_9973/4229551236.py", line 1
#     sns.distplot(titanic.age.loc[titanic['survived'] == 0].kde=False)
#                  ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
grid = sns.FacetGrid(data=titanic, col='survived')
grid.map(sns.distplot, 'age')|
# Out:
#   File "/tmp/ipykernel_9973/2158344419.py", line 2
#     grid.map(sns.distplot, 'age')|
#                                   ^
# SyntaxError: invalid syntax

# %%
 sns.countplot(data=titanic, x='survived', hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
grid = sns.FacetGrid(data=titanic, col='survived', row='pclass')
grid.map(sns.distplot. 'age')
# Out:
#   File "/tmp/ipykernel_9973/3165157127.py", line 2
#     grid.map(sns.distplot. 'age')
#                            ^
# SyntaxError: invalid syntax

# %%
grid = sns.FacetGrid(data=titanic, col='pclass', row='sex', hue='survived')
grid.map(sns.countplot, 'survived')
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(data=titanic, col='pclass', row='sex', hue='survived')
grid.map(sns.countplot, 'survived')
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
titanic.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
titanic['ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: ticket, Length: 891, dtype: object

# %%
titanic['cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: cabin, Length: 891, dtype: object

# %%
titanic.drop(['ticket', 'cabin'], axis=1, inplace=True)

# %%
import pandas as pd
import numpy as np

# NumPy는 행렬이나 일반적으로 대규모 다차원 배열을 쉽게 처리 할 수 있도록 지원하는 파

# 예시 데이터 프레임
df = pd.DataFrame([[1.2,np.nan],[3,np.nan,4],[np.nan,5,6],[np.nan,np.nan,np.nan]],columns=['a','b','c'])
df
# Out:
#      a    b    c
# 0  1.2  NaN  NaN
# 1  3.0  NaN  4.0
# 2  NaN  5.0  6.0
# 3  NaN  NaN  NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
df.dropna(how='all')
# Out:
#      a    b    c
# 0  1.2  NaN  NaN
# 1  3.0  NaN  4.0
# 2  NaN  5.0  6.0

# %%
df.fillna(0)
# Out:
#      a    b    c
# 0  1.2  0.0  0.0
# 1  3.0  0.0  4.0
# 2  0.0  5.0  6.0
# 3  0.0  0.0  0.0

# %%
titanic.isna().sum
# Out:
# <bound method DataFrame.sum of      survived  pclass   name    sex    age  sibsp  parch   fare  embarked
# 0       False   False  False  False  False  False  False  False     False
# 1       False   False  False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False  False     False
# 3       False   False  False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False  False     False
# ..        ...     ...    ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False  False     False
# 887     False   False  False  False  False  False  False  False     False
# 888     False   False  False  False   True  False  False  False     False
# 889     False   False  False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False  False     False
#
# [891 rows x 9 columns]>

# %%
I= [1, 2, 5, 5.5, 5.5, 5.5, 5.5, 6, 9, 10]

sns.distplot(1)
# Out:
# /tmp/ipykernel_9973/1896454768.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(1)
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: ylabel='Density'>

# %%
np.random.uniform(1,10,10)
# Out:
# array([3.69577133, 3.86542654, 3.68349354, 9.38262002, 9.65401642,
#        2.02351482, 7.87527598, 6.71899439, 5.39666432, 7.43396747])

# %%
import numpy as np

std= np.std(1)

# np를 이용해 std 계산, 약 2.8
mean = np.mean(I) # np를 이용한 mean 게산, 약 5.6

rand_value = np.random.uniform(mean - std, mean + std, 4) # mean Oll/

I.extend(rand_value)

# 리스트를 더해줍니다

# %%
import numpy as np

std = np.std(1)

# np를 이용해 std 계산, 약 2.8

mean = np.mean(I)

# np를 이용한 mean 게산, 약 5.6

rand_value = np.random.uniform(mean - std, mean + std, 4) #1

I.extend(rand_value)

# 리

sns.distplot(1)
# Out:
# /tmp/ipykernel_9973/2193799709.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(1)
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py:2496: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: ylabel='Density'>

# %%
rand_age = rand_age.astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/3592322223.py in <cell line: 0>()
# ----> 1 rand_age = rand_age.astype(int)
#
# NameError: name 'rand_age' is not defined

# %%
titanic.age[titanic.age. isnull ()]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
#        ..
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: age, Length: 177, dtype: float64

# %%
# 기 존 'age' 열 중 비 어 있 는 값 에 rand_age 에 들 어 있 는 값 을 차 례 로 넣 기
titanic.age[titanic.age.isnull()] = rand_age

# 아 직 도 'age' 에 nan 값 이 있
titanic.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/1056505554.py in <cell line: 0>()
#       1 # 기 존 'age' 열 중 비 어 있 는 값 에 rand_age 에 들 어 있 는 값 을 차 례 로 넣 기
# ----> 2 titanic.age[titanic.age.isnull()] = rand_age
#       3
#       4 # 아 직 도 'age' 에 nan 값 이 있
#       5 titanic.isna().sum()
#
# NameError: name 'rand_age' is not defined

# %%
sns.distplot(titanic.age)
# Out:
# /tmp/ipykernel_9973/3497382289.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic.age)
# <Axes: xlabel='age', ylabel='Density'>

# %%
titanic_original= pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/raw/titanic.csv')
sns.distplot(titanic_original.age)
# Out:
# /tmp/ipykernel_9973/2228045505.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic_original.age)
# <Axes: xlabel='age', ylabel='Density'>

# %%
titanic['embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: embarked, dtype: object

# %%
titanic['embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: embarked, dtype: object

# %%
titanic['embarked']. fillna('S', inplace=True) # 'S' CHill
titanic['embarked'].isna().sum()

#'embarked 열에서 NaN의 개수
# Out:
# /tmp/ipykernel_9973/2780641244.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['embarked']. fillna('S', inplace=True) # 'S' CHill
# np.int64(0)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   fare      891 non-null    float64
#  8   embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: name, Length: 891, dtype: object

# %%
"abcd.efg".split(',')
# Out:
# ['abcd.efg']

# %%
name = "Braund, Mr. Owen Harris"

print(name.split(' '))
# Out:
# ['Braund,', 'Mr.', 'Owen', 'Harris']

# %%
for item in name.split(' '):
  if ',' in item:
    print(item[ :- 1])
# Out:
# Braund

# %%
for name in titanic.name:
  for item in name.split(' '):
    if '.'in item:
      print(item[ :- 1])
# Out:
# Mr
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Master
# Mrs
# Mrs
# Miss
# Miss
# Mr
# Mr
# Miss
# Mrs
# Master
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Miss
# Mr
# Don
# Mrs
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Miss
# Mrs
# Mrs
# Mr
# Miss
# Miss
# Mr
# Mr
# Miss
# Mr
# Mrs
# Master
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Master
# Mr
# Miss
# Mr
# Master
# Mr
# Master
# Mrs
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Master
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mrs
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mr
# Miss
# Miss
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Miss
# Mr
# Master
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mrs
# Mrs
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mrs
# Miss
# Mrs
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Rev
# Rev
# Mrs
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Master
# Mr
# Mrs
# Mr
# Mr
# Master
# Master
# Mrs
# Mrs
# Mr
# Mr
# Mr
# ...

# %%
titanic['name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_9973/3169932332.py:1: SyntaxWarning: invalid escape sequence '\.'
#   titanic['name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: name, Length: 891, dtype: object

# %%
titanic['title'] = titanic['name'].str.extract(' ([A-Za-z]+)#.', expand=False)
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch     fare embarked title
# ...

# %%
titanic.describe(include=['0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/3554825587.py in <cell line: 0>()
# ----> 1 titanic.describe(include=['0'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11974         max            NaN      3.0
#   11975         """
# > 11976         return describe_ndframe(
#   11977             obj=self,
#   11978             include=include,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      95         )
#      96
# ---> 97     result = describer.describe(percentiles=percentiles)
#      98     return cast(NDFrameT, result)
#      99
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/methods/describe.py in describe(self, percentiles)
#     165
# ...

# %%
titanic.drop('name', inplace=True, axis=1)

# %%
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
pd.cut(titanic.age, bins=5)
# Out:
# 0      (16.336, 32.252]
# 1      (32.252, 48.168]
# 2      (16.336, 32.252]
# 3      (32.252, 48.168]
# 4      (32.252, 48.168]
#              ...
# 886    (16.336, 32.252]
# 887    (16.336, 32.252]
# 888                 NaN
# 889    (16.336, 32.252]
# 890    (16.336, 32.252]
# Name: age, Length: 891, dtype: category
# Categories (5, interval[float64, right]): [(0.34, 16.336] < (16.336, 32.252] < (32.252, 48.168] <
#                                            (48.168, 64.084] < (64.084, 80.0]]

# %%
titanic['age_band'] = pd.cut(titanic.age, bins=5)

#5개의 구간으로 잘

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked title  \
# 0         0       3    male  22.0      1      0   7.2500        S   NaN
# 1         1       1  female  38.0      1      0  71.2833        C   NaN
# 2         1       3  female  26.0      0      0   7.9250        S   NaN
# 3         1       1  female  35.0      1      0  53.1000        S   NaN
# 4         0       3    male  35.0      0      0   8.0500        S   NaN
#
#            age_band
# 0  (16.336, 32.252]
# 1  (32.252, 48.168]
# 2  (16.336, 32.252]
# 3  (32.252, 48.168]
# 4  (32.252, 48.168]

# %%
pd.pivot_table(titanic, values='survived'. columns='age_band', aggfunc='mean')
# Out:
#   File "/tmp/ipykernel_9973/4060795158.py", line 1
#     pd.pivot_table(titanic, values='survived'. columns='age_band', aggfunc='mean')
#                                                       ^
# SyntaxError: invalid syntax

# %%
pd.pivot_table(titanic, values='survived', columns='title')
# Out:
# Empty DataFrame
# Columns: []
# Index: [survived]

# %%
titanic.loc[titanic.age <= 16, 'age']
# Out:
# 7       2.0
# 9      14.0
# 10      4.0
# 14     14.0
# 16      2.0
#        ...
# 850     4.0
# 852     9.0
# 853    16.0
# 869     4.0
# 875    15.0
# Name: age, Length: 100, dtype: float64

# %%
titanic.loc[titanic['age'] <= 16, 'age'] = 0
titanic.loc[(titanic['age'] > 16) & (titanic['age'] <= 32), 'age'] = 1
titanic.loc[(titanic['age'] > 32) & (titanic['age'] <= 48), 'age'] = 2
titanic.loc[(titanic['age'] >48) & (titanic['age'] <= 64), 'age'] = 3
titanic.loc[titanic['age']> 64, 'age'] = 4
titanic.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked title  \
# 0         0       3    male  1.0      1      0   7.2500        S   NaN
# 1         1       1  female  2.0      1      0  71.2833        C   NaN
# 2         1       3  female  1.0      0      0   7.9250        S   NaN
# 3         1       1  female  2.0      1      0  53.1000        S   NaN
# 4         0       3    male  2.0      0      0   8.0500        S   NaN
#
#            age_band
# 0  (16.336, 32.252]
# 1  (32.252, 48.168]
# 2  (16.336, 32.252]
# 3  (32.252, 48.168]
# 4  (32.252, 48.168]

# %%
titanic.drop(['age_band'],axis=1,inplace=True)
titanic.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked title
# 0         0       3    male  1.0      1      0   7.2500        S   NaN
# 1         1       1  female  2.0      1      0  71.2833        C   NaN
# 2         1       3  female  1.0      0      0   7.9250        S   NaN
# 3         1       1  female  2.0      1      0  53.1000        S   NaN
# 4         0       3    male  2.0      0      0   8.0500        S   NaN

# %%
titanic.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked title
# 0         0       3    male  1.0      1      0   7.2500        S   NaN
# 1         1       1  female  2.0      1      0  71.2833        C   NaN
# 2         1       3  female  1.0      0      0   7.9250        S   NaN
# 3         1       1  female  2.0      1      0  53.1000        S   NaN
# 4         0       3    male  2.0      0      0   8.0500        S   NaN

# %%
((titanic.sibsp + titanic.parch) == 0)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
titanic['solo'] = ((titanic.sibsp + titanic.parch) == I0)

# 혼자

titanic['solo'] = titanic.solo.astype(int)
# .astype()은 데이터

titanic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/3273643216.py in <cell line: 0>()
# ----> 1 titanic['solo'] = ((titanic.sibsp + titanic.parch) == I0)
#       2
#       3 # 혼자
#       4
#       5 titanic['solo'] = titanic.solo.astype(int)
#
# NameError: name 'I0' is not defined

# %%
titanic.age = titanic.age.astype(int)
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_9973/380300038.py in <cell line: 0>()
# ----> 1 titanic.age = titanic.age.astype(int)
#       2 titanic.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
num_True = True + 2
num False = False + 2
print(num_True)
print(num_False)
# Out:
#   File "/tmp/ipykernel_9973/273484838.py", line 2
#     num False = False + 2
#         ^
# SyntaxError: invalid syntax

# %%
titanic.drop(['sibsp', 'parch'], axis=1, inplace=True)
titanic
# Out:
#      survived  pclass     sex  age     fare embarked title
# 0           0       3    male  1.0   7.2500        S   NaN
# 1           1       1  female  2.0  71.2833        C   NaN
# 2           1       3  female  1.0   7.9250        S   NaN
# 3           1       1  female  2.0  53.1000        S   NaN
# 4           0       3    male  2.0   8.0500        S   NaN
# ..        ...     ...     ...  ...      ...      ...   ...
# 886         0       2    male  1.0  13.0000        S   NaN
# 887         1       1  female  1.0  30.0000        S   NaN
# 888         0       3  female  NaN  23.4500        S   NaN
# 889         1       1    male  1.0  30.0000        C   NaN
# 890         0       3    male  1.0   7.7500        Q   NaN
#
# [891 rows x 7 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   fare      891 non-null    float64
#  5   embarked  891 non-null    object
#  6   title     0 non-null      object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 48.9+ KB

# %%
titanic['fare'] = titanic['fare'].astype(int)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   fare      891 non-null    int64
#  5   embarked  891 non-null    object
#  6   title     0 non-null      object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 48.9+ KB

# %%
titanic['age'] = ???
titanic.info()
# Out:
#   File "/tmp/ipykernel_9973/3693191644.py", line 1
#     titanic['age'] = ???
#                      ^
# SyntaxError: invalid syntax

# %%
print(titanic.title.unique())
print(titanic.title.nunique())
# Out:
# [nan]
# 0

# %%
titanic.groupby('title').count()
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, fare, embarked]
# Index: []

# %%
titanic['title'] = titanic['title'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dona', 'Dr', 'Jonkheer', 'Lady'. 'Major', 'Rev', 'Sir'], 'Other')
titanic['title'] = titanic['title'].replace( 'Mlle', 'Miss')
titanic['title'] = titanic['title'].replace('Mme', 'Mrs')
titanic['title'] = titanic['title'].replace( 'Ms', 'Miss')
# Out:
#   File "/tmp/ipykernel_9973/1049791630.py", line 1
#     titanic['title'] = titanic['title'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dona', 'Dr', 'Jonkheer', 'Lady'. 'Major', 'Rev', 'Sir'], 'Other')
#                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
titanic.title.unique()
# Out:
# array([nan], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
titanic.title = encoder.fit_transform(titanic.title)
# titanic['title'] = # 인코딩 결과를 실제 행에 적용
titanic.head()
# Out:
#    survived  pclass     sex  age  fare embarked  title
# 0         0       3    male  1.0     7        S      0
# 1         1       1  female  2.0    71        C      0
# 2         1       3  female  1.0     7        S      0
# 3         1       1  female  2.0    53        S      0
# 4         0       3    male  2.0     8        S      0

# %%
titanic.drop('name', axis=1, inplace=True)
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9973/352790403.py in <cell line: 0>()
# ----> 1 titanic.drop('name', axis=1, inplace=True)
#       2 titanic.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
titanic_original.head(3)
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
encoder.inverse_transform([0,1,2.3,4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9973/2107185224.py in <cell line: 0>()
# ----> 1 encoder.inverse_transform([0,1,2.3,4])
#
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py in inverse_transform(self, y)
#     160         )
#     161         if diff.shape[0]:
# --> 162             raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     163         y = xp.asarray(y)
#     164         return xp.take(self.classes_, y, axis=0)
#
# ValueError: y contains previously unseen labels: [1.  2.3 4. ]

# %%
genders= titanic.sex.map({'male':0,'female':1})
titanic['sex'] = genders
titanic.head()
# Out:
#    survived  pclass  sex  age  fare embarked  title
# 0         0       3    0  1.0     7        S      0
# 1         1       1    1  2.0    71        C      0
# 2         1       3    1  1.0     7        S      0
# 3         1       1    1  2.0    53        S      0
# 4         0       3    0  2.0     8        S      0

# %%
titanic.embarked.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
titanic['embarked'] = titanic.embarked.map({'S':0, 'C':1. 'Q':2])

# 소

titanic.head()
# Out:
#   File "/tmp/ipykernel_9973/713561232.py", line 1
#     titanic['embarked'] = titanic.embarked.map({'S':0, 'C':1. 'Q':2])
#                                                                    ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{'

# %%
from sklearn.linear_model import LogisticRegression

#

from sklearn.model_selection import train_test_split

# %%
def train_logistic_model(x.y):
  # 모델 정의
  model = LogisticRegression(max_iter=1000)
# Train / Test셋 분리
x_train, x_test, y_train, y_test = train_test_split(x.y.test_size=0.2)
# 모델 학습
model.fit(x_train,y_train)
# 모델 테스트 셋을 예측
Y_pred = model.predict(x_test)
print(' --- '*5 + 'train_test_split 20/80')
# 스코어 출력
print('Logistic Regression' , round(model.score(x_test, y_test) * 100. 2))
print(' --- '*5)
return model
# Out:
#   File "/tmp/ipykernel_9973/2458003198.py", line 1
#     def train_logistic_model(x.y):
#                               ^
# SyntaxError: invalid syntax

# %%
number_too_long = round(5.76543231, 2)]
print(number_too_long)
# Out:
#   File "/tmp/ipykernel_9973/1388803798.py", line 1
#     number_too_long = round(5.76543231, 2)]
#                                           ^
# SyntaxError: unmatched ']'

# %%
def predict_survival_prob(model, x):
print(' --- '*5 + 'printing survival probablity')
print('By Logistic Regression probablity of survival ', np.round(model.predict_proba(x) [ :. 1]*100.2))
print(' --- '*5)
# Out:
#   File "/tmp/ipykernel_9973/499442576.py", line 2
#     print(' --- '*5 + 'printing survival probablity')
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
x = titanic.drop('survived', axis=1)
y = titanic.survived

print(x)
print(y)
# Out:
#      pclass  sex  age  fare embarked  title
# 0         3    0  1.0     7        S      0
# 1         1    1  2.0    71        C      0
# 2         3    1  1.0     7        S      0
# 3         1    1  2.0    53        S      0
# 4         3    0  2.0     8        S      0
# ..      ...  ...  ...   ...      ...    ...
# 886       2    0  1.0    13        S      0
# 887       1    1  1.0    30        S      0
# 888       3    1  NaN    23        S      0
# 889       1    0  1.0    30        C      0
# 890       3    0  1.0     7        Q      0
#
# [891 rows x 6 columns]
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
model = train_logistic_model (x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/3728458857.py in <cell line: 0>()
# ----> 1 model = train_logistic_model (x, y)
#
# NameError: name 'train_logistic_model' is not defined

# %%
print(x.iloc[1], '#n', y.iloc[1])
# Out:
# pclass        1
# sex           1
# age         2.0
# fare         71
# embarked      C
# title         0
# Name: 1, dtype: object #n 1

# %%
model.predict([x.iloc[1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/2696124090.py in <cell line: 0>()
# ----> 1 model.predict([x.iloc[1]])
#
# NameError: name 'model' is not defined

# %%
encoder.transform(['Mrs'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_encode.py in _encode(values, uniques, check_unknown)
#     234         try:
# --> 235             return _map_to_integer(values, uniques)
#     236         except KeyError as e:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_encode.py in _map_to_integer(values, uniques)
#     173     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 174     return xp.asarray([table[v] for v in values], device=device(values))
#     175
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_encode.py in __missing__(self, key)
#     166             return self.nan_value
# --> 167         raise KeyError(key)
#     168
#
# KeyError: 'Mrs'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
test_input = [[3,1,2,20,0,3,0]]
#3등석, 여자(1), 39세(age_band 2), 20 유로(운임료), embarked(southhampton)

predict_survival_prob(model, test_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/1420983912.py in <cell line: 0>()
#       2 #3등석, 여자(1), 39세(age_band 2), 20 유로(운임료), embarked(southhampton)
#       3
# ----> 4 predict_survival_prob(model, test_input)
#
# NameError: name 'predict_survival_prob' is not defined

# %%
from sklearn.datasets import make_blobs
#군집을 위한 가상 데이터 생성
x,y=make_blobs(n_samples=150, n_features=2, centers=3,
cluster_std=0.5, shuffle=True, random_state=0)
print(f"x.shape:{x.shape}, y.shape:{y.shape}")
# Out:
# x.shape:(150, 2), y.shape:(150,)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
#초기 데이터 시각화
import matplotlib.pyplot as plt
plt.scatter(x[:,0],
plt.grid()
plt.show()
# Out:
#   File "/tmp/ipykernel_9973/47866404.py", line 3
#     plt.scatter(x[:,0],
#                ^
# SyntaxError: '(' was never closed

# %%
from sklearn.cluster import KMeans
#초기 클러스터 중심: 랜덤 할당
init_centroid="random'
# Out:
#   File "/tmp/ipykernel_9973/2162476696.py", line 3
#     init_centroid="random'
#                   ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
kmodel=KMeans(n_clusters=3, init=init_kentroid, random_state=0)
pred=kmodel.fit_predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/2366877507.py in <cell line: 0>()
# ----> 1 kmodel=KMeans(n_clusters=3, init=init_kentroid, random_state=0)
#       2 pred=kmodel.fit_predict(x)
#
# NameError: name 'KMeans' is not defined

# %%
x[pred == 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9973/122727945.py in <cell line: 0>()
# ----> 1 x[pred == 1]
#
# NameError: name 'pred' is not defined

# %%
plt.scatter(x[pred == 2,0].x[pred == 2,1],marker='v',s=50, c='blue', label='cluster3')
plt.scatter(kmodel.cluster_centers_[:,0],kmodel.cluster_centers_[:,1],
marker='*',s=80, c='red', label='center
plt.legend()
plt.grid()
plt.show()

plt.scatter(x[pred == 0.0].x[pred == 0.1].marker='o',s=50, c='yellow', label='cluster1')
plt.scatter(x[pred == 1,0],x[pred == 1,1],marker='s',s=50, c='green', label='cluster2')
# Out:
#   File "/tmp/ipykernel_9973/3074269705.py", line 3
#     marker='*',s=80, c='red', label='center
#                                     ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
sse=[]
for i in range(1,11):
km=KMeans(n_clusters=i, init='k-means++',random_state=0)
km.fit(x)
sse.append(km.inertia_)#오차 제곱의 합
print('-'*20)
print(sse[3])
print('-'*20)
plt.plot(range(1,11), sse, marker="o")
plt.axvline(x=3, color="r")
plt.axhline(y=sse[3].color='r')
plt.xlabel("Number of Cluster")
plt.ylabel("sse")
plt.show()
elbow(x)

def elbow(x):
# Out:
#   File "/tmp/ipykernel_9973/397794854.py", line 3
#     km=KMeans(n_clusters=i, init='k-means++',random_state=0)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2
